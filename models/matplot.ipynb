# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.style.use('bmh')

# %%
# This line helps because the background color of my vsc is black
# Otherwise I cannot seer the labels in the plots.
plt.rcParams['figure.facecolor'] = 'white'

# %%
# Let's plot a simple line between two pairs of points.
# Matplot has an object and state interface. We will use the object one
fig, ax = plt.subplots()
ax.plot([1, 3], [2, 4])
# Basically, we first create a figure, which can then have several axes.
# Also, we can change proprties of the axes
ax.set_xlabel('This is the X Axis label')
ax.set_ylabel('This is the Y Axis label')
ax.set_title('This is the title of the graph')
ax.legend
# Out:
# <bound method Axes.legend of <matplotlib.axes._subplots.AxesSubplot object at 0x7fd25a174cd0>>

# %%
# Another way to create a figure is via the figure method
fig, ax = plt.subplots(figsize = (5, 5))
ax.plot([5,48,6,54,5,6,8,6,2,99,6,5])

# %% [markdown]
# Scatterplot

# %%
weights = np.arange(60, 90, 0.4)
heights = np.arange(170, 200, 0.6)
extra_weights = [73, 78, 62, 84, 83, 72]
extra_heights = [160, 165, 180, 200, 180, 185]
weights = np.append(weights, extra_weights)
heights = np.append(heights, extra_heights)
print(weights)
print(heights)
# Out:
# [60.  60.4 60.8 61.2 61.6 62.  62.4 62.8 63.2 63.6 64.  64.4 64.8 65.2
#  65.6 66.  66.4 66.8 67.2 67.6 68.  68.4 68.8 69.2 69.6 70.  70.4 70.8
#  71.2 71.6 72.  72.4 72.8 73.2 73.6 74.  74.4 74.8 75.2 75.6 76.  76.4
#  76.8 77.2 77.6 78.  78.4 78.8 79.2 79.6 80.  80.4 80.8 81.2 81.6 82.
#  82.4 82.8 83.2 83.6 84.  84.4 84.8 85.2 85.6 86.  86.4 86.8 87.2 87.6
#  88.  88.4 88.8 89.2 89.6 73.  78.  62.  84.  83.  72. ]
# [170.  170.6 171.2 171.8 172.4 173.  173.6 174.2 174.8 175.4 176.  176.6
#  177.2 177.8 178.4 179.  179.6 180.2 180.8 181.4 182.  182.6 183.2 183.8
#  184.4 185.  185.6 186.2 186.8 187.4 188.  188.6 189.2 189.8 190.4 191.
#  191.6 192.2 192.8 193.4 194.  194.6 195.2 195.8 196.4 197.  197.6 198.2
#  198.8 199.4 160.  165.  180.  200.  180.  185. ]

# %%
fig, ax = plt.subplots(figsize = (12, 5))
ax.scatter(weights, heights)
ax.set_xlabel('Weight')
ax.set_ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')
